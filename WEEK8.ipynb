# %% [markdown]
# #W8/1

# %%
class Cylinder():
    def __init__(self, r, h):
        
        self.r = r
        self.h = h

    def calcVolume(self):
        return f"{3.14 * self.r**2 * self.h:.2f}"
    
    def calcSurfaceArea(self):
        return f"{2*3.14*(self.r + self.h):.2f}"
    
c = Cylinder(3, 5)
print(c.calcSurfaceArea())
print(c.calcVolume())
# Out:
# 50.24
# 141.30

# %% [markdown]
# #W8/2

# %%
class Date:
    def __init__(self, day, month, year):
        self.day = day
        self.month = month
        self.year = year

    def is_leap_year(self):
        return (self.year % 400 == 0) or (self.year % 4 == 0 and self.year % 100 != 0)

    def is_valid(self):
        if self.month < 1 or self.month > 12:
            return False

        days_in_month = [31, 28, 31, 30, 31, 30,
                         31, 31, 30, 31, 30, 31]

        if self.is_leap_year():
            days_in_month[1] = 29

        if self.day < 1 or self.day > days_in_month[self.month - 1]:
            return False

        return True

    def next_day(self):
        days_in_month = [31, 28, 31, 30, 31, 30,
                         31, 31, 30, 31, 30, 31]

        if self.is_leap_year():
            days_in_month[1] = 29

        self.day += 1

        if self.day > days_in_month[self.month - 1]:
            self.day = 1
            self.month += 1

            if self.month > 12:
                self.month = 1
                self.year += 1

        return self


# ===== MAIN =====
s = input().strip()

try:
    d, m, y = map(int, s.split("/"))
    date = Date(d, m, y)

    if not date.is_valid():
        print("INVALID")
    else:
        next_date = date.next_day()
        print(f"{next_date.day:02d}/{next_date.month:02d}/{next_date.year}")
except:
    print("INVALID")
# Out:
# 1/1/2008
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #W8/3

# %%
class Point():
    def __init__(self, x, y):
        
        self.x = x
        self.y = y


    def checkRoot(self):
        return self.x == 0 and self.y == 0

    def getDistFromRoot(self) 
        return (self.x**2 + self.y**2)*0.5 

    def checkOnY(self):
        return self.x == 0     
    
    def checkOnX(self):
        return self.y == 0
# Out:
# [2, 3, 9, 10, 12, 20, 29, 39]
# [2, 3, 9, 10, 12, 20, 29, 39]

# %% [markdown]
# #W8/4

# %%
class Calculator:
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2

    def add(self):
        return self.num1 + self.num2

    def subtract(self):
        return self.num1 - self.num2

    def product(self):
        return self.num1 * self.num2

    def divide(self):
        if self.num2 == 0:
            return "Error: Division by zero"
        return self.num1 / self.num2

    def power(self):
        return self.num1 ** self.num2

    def mod(self):
        if self.num2 == 0:
            return "Error: Division by zero"
        return self.num1 % self.num2

    def set_numbers(self, num1, num2):
        self.num1 = num1
        self.num2 = num2

def main():
    try:
        n1 = float(input("Enter first number: "))
        n2 = float(input("Enter second number: "))
        calc = Calculator(n1, n2)
        
        while True:
            print("\n1. Add\n2. Subtract\n3. Product\n4. Divide\n5. Power\n6. Mod\n7. Set Numbers")
            choice = input("Select operation (1-7): ")
            
            if choice == '1': print("Result:", calc.add())
            elif choice == '2': print("Result:", calc.subtract())
            elif choice == '3': print("Result:", calc.product())
            elif choice == '4': print("Result:", calc.divide())
            elif choice == '5': print("Result:", calc.power())
            elif choice == '6': print("Result:", calc.mod())
            elif choice == '7':
                n1 = float(input("Enter new first number: "))
                n2 = float(input("Enter new second number: "))
                calc.set_numbers(n1, n2)
            
            exit_choice = input("Do you want to exit (yes/no)? ").lower()
            if exit_choice == "yes":
                break
    except ValueError:
        print("Invalid input")

if __name__ == "__main__":
    main()
# Out:
# 2

# %% [markdown]
# #W8/5

# %%
class ShoppingCart:
    def __init__(self):
        self.items = []

    def add_item(self, name, price):
        self.items.append({"name": name, "price": price})

    def remove_item(self, name):
        self.items = [item for item in self.items if item["name"] != name]

    def is_empty(self):
        return len(self.items) == 0

    def calculate_total(self):
        total = 0
        for item in self.items:
            total += item["price"]
        return total

    def display_items(self):
        return self.items

    def clear_cart(self):
        self.items = []

def run_calculator():
    n1 = float(input())
    n2 = float(input())
    calc = Calculator(n1, n2)
    while True:
        choice = input()
        if choice == '1': print(calc.add())
        elif choice == '2': print(calc.subtract())
        elif choice == '3': print(calc.product())
        elif choice == '4': print(calc.divide())
        elif choice == '5': print(calc.power())
        elif choice == '6': print(calc.mod())
        elif choice == '7':
            n1 = float(input())
            n2 = float(input())
            calc.set_numbers(n1, n2)
        
        if input().lower() in ["yes", "yes", "yes"]:
            break

def run_shopping_cart():
    cart = ShoppingCart()
    while True:
        choice = input()
        if choice == '2':
            name = input()
            price = float(input())
            cart.add_item(name, price)
        elif choice == '3':
            name = input()
            cart.remove_item(name)
        elif choice == '4':
            print(cart.is_empty())
        elif choice == '5':
            print(cart.calculate_total())
        elif choice == '6':
            print(cart.display_items())
        elif choice == '7':
            cart.clear_cart()
            
        if input().lower() == "yes":
            break
# Out:
# 2
# 3
# 2
# 3
# 4
# 1
# 6
# -1
# 2
# 3
# 2
# 14

# %% [markdown]
# #W8/6

# %%
class Rectangle:
    def __init__(self, w, h):
        self.w = w
        self.h = h

    def area(self):
        return self.w * self.h

    def perimeter(self):
        return 2 * (self.w + self.h)

    def scale(self, k):
        self.w *= k
        self.h *= k
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #W8/7

# %%
class Fraction:
    def __init__(self, num, den):
        if den == 0:
            raise ValueError("Mẫu số phải khác 0")
        
        common = self._gcd(abs(num), abs(den))
        self.num = num // common
        self.den = den // common
        
        if self.den < 0:
            self.num = -self.num
            self.den = -self.den

    def _gcd(self, a, b):
        while b:
            a, b = b, a % b
        return a

    def add(self, other):
        new_num = self.num * other.den + other.num * self.den
        new_den = self.den * other.den
        return Fraction(new_num, new_den)

    def sub(self, other):
        new_num = self.num * other.den - other.num * self.den
        new_den = self.den * other.den
        return Fraction(new_num, new_den)

    def mul(self, other):
        new_num = self.num * other.num
        new_den = self.den * other.den
        return Fraction(new_num, new_den)

    def div(self, other):
        if other.num == 0:
            raise ValueError("Không thể chia cho phân số có tử bằng 0")
        new_num = self.num * other.den
        new_den = self.den * other.num
        return Fraction(new_num, new_den)

    def __str__(self):
        
        return f"{self.num}/{self.den}"
# Out:
# 1 -1 (-1, 2, 9, 3, 2, 1)

# %% [markdown]
# #W8/8

# %%
class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = float(balance)

    def deposit(self, x):
        self.balance += float(x)

    def withdraw(self, x):
        amount = float(x)
        if amount <= self.balance:
            self.balance -= amount

    def __str__(self):
        return f"{self.owner}: {self.balance:.2f}"
# Out:
# {'a': 2, 'b': 2, 'c': 1, 'd': 1}

# %% [markdown]
# #W8/9

# %%
class Student:
    def __init__(self, name):
        self.name = name
        self.scores = []

    def add_score(self, subject, score):
        self.scores.append(float(score))

    def avg(self):
        return sum(self.scores) / len(self.scores) if self.scores else 0.0

    def rank(self):
        average = self.avg()
        if average >= 8: return "Excellent"
        if average >= 6.5: return "Good"
        if average >= 5: return "Average"
        return "Poor"
# Out:
# {'a': 1, 'b': 6, 'c': 3}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# #W8/10

# %%
class Book:
    def __init__(self, title, author, year):
        self.title = title
        self.author = author
        self.year = int(year)

class Library:
    def __init__(self):
        self.books = []

    def add(self, book):
        self.books.append(book)

    def count_by_author(self, name):
        return sum(1 for b in self.books if b.author == name)

    def find_by_year(self, y):
        return sum(1 for b in self.books if b.year == int(y))
# Out:
# 9 20

# %% [markdown]
# #W8/11

# %%
import math

class Point:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z

    def __sub__(self, other):
        return Point(self.x - other.x, self.y - other.y, self.z - other.z)

    def cross(self, other):
        return Point(self.y * other.z - self.z * other.y,
                     self.z * other.x - self.x * other.z,
                     self.x * other.y - self.y * other.x)

    def dot(self, other):
        return self.x * other.x + self.y * other.y + self.z * other.z

    def magnitude(self):
        return math.sqrt(self.x**2 + self.y**2 + self.z**2)
# Out:
# (10, 2, 8, 4, 6)
# (1, 9, 3, 7, 5)

# %% [markdown]
# #W8/12

# %%
class ComplexNumber:
    def __init__(self, realPart, imaginaryPart):
        self.realPart = float(realPart)
        self.imaginaryPart = float(imaginaryPart)

    def multiply(self, other):
        new_real = (self.realPart * other.realPart) - (self.imaginaryPart * other.imaginaryPart)
        new_imag = (self.realPart * other.imaginaryPart) + (self.imaginaryPart * other.realPart)
        return ComplexNumber(new_real, new_imag)

    def __str__(self):
        return f"{int(self.realPart)} {int(self.imaginaryPart)}"
# Out:
# 1

# %% [markdown]
# #W8/13

# %%
class Triangle:
    def __init__(self, initEdge1, initEdge2, initEdge3):
        self.edge1 = initEdge1
        self.edge2 = initEdge2
        self.edge3 = initEdge3

    def getArea(self):
        a, b, c = self.edge1, self.edge2, self.edge3
        if a + b > c and a + c > b and b + c > a:
            s = (a + b + c) / 2
            area = (s * (s - a) * (s - b) * (s - c)) ** 0.5
            return area
        return -1
# Out:
# {'1': 'a', '2': 'a', '3': 'a', '4': 'a'}
