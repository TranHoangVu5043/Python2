# %% [markdown]
# # W2A1

# %%
print("Hello Word!")
# Out:
# Hello Word!

# %% [markdown]
# # W2A2

# %%
n = input("Ten cua ban: ")
print("Hello " + n)
# Out:
# Hello Vu

# %% [markdown]
# # W2A3

# %%
a = int(input("Nhap so a: "))
b = int(input("Nhap so b: "))

print("Tong: ", a + b)
print("Hieu: ", a - b)
print("Tich: ", a * b)
print("Thuong: ", a / b)

print("Du", a % b)
print("Nguyen", a // b)

print("So thap phan:", f"{(a / b):.2f}")
# Out:
# Tong:  5
# Hieu:  -1
# Tich:  6
# Thuong:  0.6666666666666666
# Du 2
# Nguyen 0
# So thap phan: 0.67

# %% [markdown]
# # W2A4

# %%
a1, a2, a3, b1, b2, c1, c2 = map(float, input("Nhap  dau diem: ").split(" ")); 

print("Diem trung binh: ", (a1 + a2 + a3 + (b1 + b2) * 2 + (c1 + c2) * 3) / 10)
# Out:
# Diem trung binh:  6.3

# %% [markdown]
# # W2A5

# %%
a, b = input("Nhap so: ").split() 

print(int(a)**int(b))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a, b = input("Nhap so: ").split()
#       3 print(int(a)**int(b))
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# # W2A6

# %%
s = input("Nhap chu: ")

print(ord(s))
print(s.upper())
# Out:
# 65
# A

# %% [markdown]
# # W2A7

# %%
print(((13 ** 2) * 3 ) + 5)
print(13**2*3 + 5)
# Out:
# 512
# 512

# %% [markdown]
# # W2A8

# %%
def conv(c):
    return (c * 9/5) + 32

print(conv(float(input("Nhap do C: "))))
# Out:
# 37.40

# %% [markdown]
# # W2A9

# %%
x = int(input("Gia tien: "))

def realPrice(x):
    return x + 10 + x * 0.3 + x * 0.1

print(realPrice(x))
# Out:
# 56.20

# %% [markdown]
# # W2A10

# %%
m = input("Nhap ten: ").split()
m.reverse()

if len(m) > 1:
    print("Hello " + ", ".join(m[:-1]) + " and " + m[-1])
else:
    print("Hello " + m[0])
# Out:
# Hi border, main and alice.

# %% [markdown]
# # W2A11

# %%
h = int(input("Nhập số giờ: "))
m = int(input("Nhập số phút: "))

print(h * 60**2 + m * 60)
# Out:
# 7380

# %% [markdown]
# # W2A12

# %%
n = input("Do dai canh: ")

print((int(n**2)*6))
# Out:
# 96

# %% [markdown]
# #W2A13

# %%
a = input("So a: ")
b = input("So b: ")

print((int(a) * int(b)) % 10 )
# Out:
# 6

# %% [markdown]
# # W2A14

# %%
a = input("So a: ")
b = input("So b: ")

print(a, b)

a, b = b, a 

print(a, b)
# Out:
# Sau khi hoán đổi:
# a = 4
# b = 3

# %% [markdown]
# # W2A15

# %%
n = int(input("Nhập số nguyên dương n: "))

star_number = 6 * n * (n - 1) + 1

print(star_number)
# Out:
# 73

# %% [markdown]
# # W2A16

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# # W2A17

# %%
for x in range(0, 5, 2):
    print("*" * (x + 1))
# Out:
# *
# ***
# *****

# %% [markdown]
# # W2A18

# %%
print("""
      #####  ####   #####  #####  
        #    #   #    #      #    
        #    #   #    #      #    
        #    #   #    #      #    
        #    ####     #      #    
      """)
# Out:
#       #####  ####   #####  #####
#         #    #   #    #      #
#         #    #   #    #      #
#         #    #   #    #      #
#         #    ####     #      #

# %% [markdown]
# # W2A19

# %%
days = [
    "Monday",
    "Tuesday",
    "Wednesday",
    "Thursday",
    "Friday",
    "Saturday",
    "Sunday"
]

for day in days:
    print(day)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# # W2A20

# %%
months = [
    "January",
    "February",
    "March",
    "April",
    "May",
    "June",
    "July",
    "August",
    "September",
    "October",
    "November",
    "December"
]

for month in months:
    print(month)
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# # W2A21

# %%
for i in range(10):
    print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
